# %% [markdown]
# # Como interagir com este caderno do Jupyter
#
# Nesta atividade, você usará um caderno do Jupyter, que integra tanto texto quanto código. As caixas cinza contêm código executável, que você executará para ver sua saída. O texto entre o código fornece instruções.

# %% [markdown]
# ## Passo 1: Instalação das bibliotecas necessárias
#
# Execute a célula abaixo, que instala todas as bibliotecas necessárias.

# %%
# !pip install pandas matplotlib plotly.express nbformat

# %% [markdown]
# ## Passo 2: Carregando e explorando os dados
#
# Execute a célula abaixo, que importa todas as bibliotecas necessárias, carrega `music_data.csv`, e mostra as primeiras 5 linhas para obter informações sobre as colunas. Esta célula não muda.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
music_data = pd.read_csv('music_data.csv')

# Display the first 5 rows
print("First 5 rows of the dataset:")
print(music_data.head())

# Get information about the columns (data types and non-null values)
print("\nColumn information:")
print(music_data.info())
# Out:
# First 5 rows of the dataset:
#    song_id artist_name      genre  release_year  duration_seconds  tempo  \
# 0        1    Artist G       Rock          2011               270    172
# 1        2    Artist D        Pop          2000               246    146
# 2        3    Artist H       Jazz          2005               274    155
# 3        4    Artist E       Jazz          2022               249    105
# 4        5    Artist G  Classical          1998               136     95
#
#      energy  danceability   valence  acousticness  popularity  listen_count  \
# 0  0.504482      0.478219  0.817431      0.091869          59         43460
# 1  0.858454      0.412011  0.479169      0.488496          42         91397
# 2  0.815048      0.550194  0.634046      0.230904          75         73847
# 3  0.557396      0.246641  0.237856      0.464991          99         94607
# 4  0.750523      0.784637  0.253831      0.123490          67         90106
#
#    user_age
# 0        23
# ...

# %% [markdown]
# ## Passo 3: Gerando um gráfico de barras usando o módulo pyplot do Matplotlib
#
# Siga os passos nas instruções e execute a célula abaixo.

# %%
# Count the occurrences of each unique value in the `genre` column
genre_counts = music_data['genre'].value_counts()   
genre_counts
# Out:
# genre
# Pop           16
# Jazz          15
# Country       10
# Hip-Hop       10
# R&B            9
# Electronic     9
# Classical      8
# Folk           8
# Indie          8
# Rock           7
# Name: count, dtype: int64

# %%
# Sort the genres by frequency in descending order and select the top 10 genres
top_10_genres = genre_counts.head(10)
top_10_genres
# Out:
# genre
# Pop           16
# Jazz          15
# Country       10
# Hip-Hop       10
# R&B            9
# Electronic     9
# Classical      8
# Folk           8
# Indie          8
# Rock           7
# Name: count, dtype: int64

# %%
# Create a bar chart to display the top 10 genres by frequency
plt.figure(figsize=(10, 6)) 

top_10_genres.plot(kind='bar')

# Add title and labels
plt.title('Top 10 Genres by Frequency')  
plt.xlabel('Genre')  
plt.ylabel('Number of Songs')  

# Display the plot using plt.show()
plt.show()

# %% [markdown]
# ## Passo 4: Gerar um histograma usando plt.figure() do Matplotlib
#
# Siga os passos nas instruções e execute a célula abaixo.

# %%
# Extract the duration_seconds column
duration_seconds = music_data['duration_seconds'] 

# Create a histogram to display the distribution of `duration_seconds`
plt.figure(figsize = (8,5))
plt.hist(duration_seconds, bins=20, color='skyblue', edgecolor='black', rwidth=0.8)

# Add title and labels
plt.title('Distribution of Song Durations')
plt.xlabel('Duration (seconds)')
plt.ylabel('Frequency')

# Display the plot using plt.show()
plt.show()

# %% [markdown]
# ## Passo 5: Gerar um histograma usando plt.hist() do Matplotlib
#
# Siga os passos nas instruções e execute a célula abaixo.

# %%
# Extract the popularity column
popularity = music_data['popularity']

# Create a histogram to display the distribution of popularity 
plt.figure(figsize=(8, 5))  # Set the figure size for better readability

# Plot the histogram with customized bins and colors
plt.hist(popularity, bins=10, color='green', edgecolor='black')  

# Add title and labels
plt.title('Distribution of Song Popularity')
plt.xlabel('Popularity')
plt.ylabel('Frequency')

# Display the plot using plt.show()
plt.show()

# %% [markdown]
# ## Passo 6: Gerar mapas de calor usando Plotly
#
# Siga os passos descritos no seu documento de instruções para completar o código abaixo. Clique em executar para ver os resultados.

# %%
import plotly.express as px

# Create a new dataframe numeric_features containing only the 
# numeric columns we want to analyze
numeric_features = music_data[['tempo', 'energy', 'danceability', 
                               'valence', 'acousticness', 'popularity']]

# Compute the correlation matrix 
correlation_matrix = numeric_features.corr()
correlation_matrix
# Out:
#                  tempo    energy  danceability   valence  acousticness  \
# tempo         1.000000 -0.151135      0.041212 -0.098075     -0.064776
# energy       -0.151135  1.000000     -0.087872  0.257056      0.095076
# danceability  0.041212 -0.087872      1.000000 -0.033731     -0.110073
# valence      -0.098075  0.257056     -0.033731  1.000000      0.152736
# acousticness -0.064776  0.095076     -0.110073  0.152736      1.000000
# popularity    0.058102 -0.056603     -0.053124  0.097868      0.107704
#
#               popularity
# tempo           0.058102
# energy         -0.056603
# danceability   -0.053124
# valence         0.097868
# acousticness    0.107704
# popularity      1.000000

# %%
# Create and display a heatmap using Plotly
plt = px.imshow(correlation_matrix,
                x=correlation_matrix.columns,
                y=correlation_matrix.columns,
                color_continuous_scale="RdBu",  # Use a built-in Plotly colorscale
                text_auto=".2f",  
                title="Correlation Matrix of Music Features"
               )

plt.show()

# %% [markdown]
# ## Passo 7: Gerar gráficos de violino usando Plotly
#
# Siga os passos descritos no seu documento de instruções para completar o código abaixo. Clique em executar para ver os resultados.

# %%
import plotly.express as px

plt = px.violin(music_data, 
                x='genre', 
                y='popularity', 
                box=True,
                title="Popularity Distribution Across Genres")

plt.show()

# %% [markdown]
# Você chegou ao final deste exercício.

# %% [markdown]
# ### Qual das seguintes funções do Matplotlib é usada para criar um histograma, visualizando a distribuição de um conjunto de dados numéricos?
#
# - plt.bar()
# - plt.plot()
# - **plt.hist()**
# - plt.scatter()
#
# > Correto! plt.hist() é especificamente projetado para gerar histogramas que permitem visualizar a distribuição de dados numéricos.
#
# ### Qual das seguintes funções do Matplotlib pode ser usada para visualizar a correlação entre múltiplas características numéricas em um conjunto de dados?
#
# - O gráfico de violino
# - **Mapa de calor**
# - Gráfico de linha
# - Gráfico de categoria
#
# > Correto! Um mapa de calor é ideal para visualizar matrizes de correlação, onde a intensidade da cor representa a força da correlação entre características.
#
# ### No Matplotlib, qual função é usada principalmente para criar gráficos de linhas, frequentemente utilizados para visualizar tendências ao longo do tempo?
#
# - **plt.plot()**
# - plt.hist()
# - plt.scatter()
# - plt.bar()
#
# > Correto: plt.plot() é a função principal para gerar gráficos lineares no Matplotlib.
#
# ### Qual é o objetivo principal de agrupar ou discretizar os dados de idade ao criar visualizações?
#
# - **Melhorar a legibilidade e interpretabilidade da visualização, especialmente quando se trata de uma ampla gama de valores de idade**
# - Para alterar a distribuição dos dados subjacentes
# - Para aumentar a complexidade da visualização.
# - Para que a visualização seja menos informativa
#
# > Correto! O agrupamento ajuda a evitar saturação e facilita a identificação de tendências entre grupos de idade.
#
# ### Qual é a função principal da função px.imshow() no Plotly Express?
#
# - Para visualizar matrizes 2D como imagens ou mapas de calor
# - Gerar gráficos de superfície em 3D de dados numéricos
# - Gerar gráficos de dispersão para explorar as relações entre duas variáveis numéricas
# - **Criar gráficos lineares interativos para visualizar as tendências ao longo do tempo**
#
# > Correto! px.imshow() é projetado para visualizar matrizes 2D como imagens ou mapas de calor.
#
# ### No contexto da análise do conjunto de dados musicais, o que pode ser obtido de um gráfico de linhas que mostra "Total de escutas por ano de publicação"?
#
# - Distribuição da popularidade das músicas nos diferentes gêneros
# - **Como as pautas de consumo de música mudaram ao longo do tempo, o que pode indicar períodos de maior ou menor atividade de escuta.**
# - O gênero mais popular entre os diferentes grupos de idade
# - A correlação entre a duração de uma música e sua popularidade
#
# > Correto! Um gráfico de linhas que acompanha o total de escutas por ano de publicação revela diretamente as tendências do consumo de música ao longo do tempo.
#
# ### Qual das seguintes afirmações reflete com exatidão um aspecto-chave da atividade do Notebook Jupyter?
#
# - **A visualização de dados é uma ferramenta poderosa para descobrir tendências, padrões e perspectivas que podem informar a tomada de decisões**
# - Visualização de dados consiste principalmente em criar gráficos complexos e visualmente impactantes
# - Visualização de dados consiste principalmente em criar gráficos complexos e visualmente impactantes
# - Matplotlib é a única biblioteca necessária para todas as tarefas de visualização de dados em Python
# - As decisões da equipe de marketing devem basear-se exclusivamente nas visualizações criadas
#
# > Correto! Captura a essência da atividade, destacando o valor da visualização na exploração e análise de dados
